# %% [markdown]
# <a href="https://colab.research.google.com/github/beinghorizontal/wav2vec2/blob/main/Fine_Tune_XLSR_Wav2Vec2_large-en-in.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import datasets
# !pip install datasets
import datasets
timit = datasets.load_dataset("crossdelenna/en_in", use_auth_token='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')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 5.2 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 54.2 MB/s
# Collecting fsspec[http]>=2021.11.1
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 58.7 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 11.0 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 53.5 MB/s
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.7.1)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 62.9 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 61.9 MB/s
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, pyyaml, fsspec, xxhash, responses, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed datasets-2.4.0 fsspec-2022.7.1 huggingface-hub-0.8.1 multiprocess-0.70.13 pyyaml-6.0 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0
# Downloading:   0%|          | 0.00/987 [00:00<?, ?B/s]
# WARNING:datasets.builder:Using custom data configuration crossdelenna--en_in-98fe67c47b829786
# Downloading and preparing dataset csv/default (download: 1.43 GiB, generated: 2.14 GiB, post-processed: Unknown size, total: 3.57 GiB) to /root/.cache/huggingface/datasets/crossdelenna___parquet/crossdelenna--en_in-98fe67c47b829786/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/186M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/189M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/295M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/291M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/289M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/282M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/crossdelenna___parquet/crossdelenna--en_in-98fe67c47b829786/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
timit
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['input_values', 'input_length', 'labels'],
#         num_rows: 850
#     })
#     train: Dataset({
#         features: ['input_values', 'input_length', 'labels'],
#         num_rows: 2548
#     })
# })

# %%
timit2 = datasets.load_dataset("crossdelenna/en_in2", use_auth_token='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')
# Out:
# Downloading:   0%|          | 0.00/991 [00:00<?, ?B/s]
# WARNING:datasets.builder:Using custom data configuration crossdelenna--en_in2-417fc25a4bca1da2
# Downloading and preparing dataset csv/default (download: 1.98 GiB, generated: 2.87 GiB, post-processed: Unknown size, total: 4.85 GiB) to /root/.cache/huggingface/datasets/crossdelenna___parquet/crossdelenna--en_in2-417fc25a4bca1da2/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/264M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/264M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/324M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/318M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/324M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/316M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/320M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/crossdelenna___parquet/crossdelenna--en_in2-417fc25a4bca1da2/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
timit2
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['input_values', 'input_length', 'labels'],
#         num_rows: 1436
#     })
#     train: Dataset({
#         features: ['input_values', 'input_length', 'labels'],
#         num_rows: 4305
#     })
# })

# %%
#assert timit2.features.type == timit.features.type
timit_large_train = datasets.concatenate_datasets([timit["train"],timit2["train"]])
timit_large_test = datasets.concatenate_datasets([timit["test"],timit2["test"]])

# %%
timit_large_train
# Out:
# Dataset({
#     features: ['input_values', 'input_length', 'labels'],
#     num_rows: 6853
# })

# %%
timit_large_test
# Out:
# Dataset({
#     features: ['input_values', 'input_length', 'labels'],
#     num_rows: 2286
# })

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Aug 14 08:28:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# !unzip "/content/drive/MyDrive/checkpoints_large.zip" -d "/content/"
# Out:
# Mounted at /content/drive
# Archive:  /content/drive/MyDrive/checkpoints_large.zip
#    creating: /content/wav2vec2-large-en-in/
#    creating: /content/wav2vec2-large-en-in/checkpoint-1980/
#    creating: /content/wav2vec2-large-en-in/runs/
#    creating: /content/wav2vec2-large-en-in/runs/Aug13_19-08-29_fbc275f23007/
#    creating: /content/wav2vec2-large-en-in/runs/Aug13_21-33-30_a165fbd76f81/
#    creating: /content/wav2vec2-large-en-in/runs/Aug13_23-55-37_1ec0da968c95/
#    creating: /content/wav2vec2-large-en-in/runs/Aug14_03-55-58_e9a54e51d3b8/
#    creating: /content/wav2vec2-large-en-in/runs/Aug13_23-55-37_1ec0da968c95/1660435275.5538704/
#   inflating: /content/wav2vec2-large-en-in/runs/Aug13_23-55-37_1ec0da968c95/events.out.tfevents.1660435275.1ec0da968c95.71.0
#   inflating: /content/wav2vec2-large-en-in/runs/Aug13_23-55-37_1ec0da968c95/1660435275.5538704/events.out.tfevents.1660435275.1ec0da968c95.71.1
#    creating: /content/wav2vec2-large-en-in/runs/Aug13_19-08-29_fbc275f23007/1660418006.09353/
#   inflating: /content/wav2vec2-large-en-in/runs/Aug13_19-08-29_fbc275f23007/events.out.tfevents.1660418006.fbc275f23007.591.0
#   inflating: /content/wav2vec2-large-en-in/runs/Aug13_19-08-29_fbc275f23007/1660418006.09353/events.out.tfevents.1660418006.fbc275f23007.591.1
#    creating: /content/wav2vec2-large-en-in/runs/Aug14_03-55-58_e9a54e51d3b8/1660449712.9079666/
#   inflating: /content/wav2vec2-large-en-in/runs/Aug14_03-55-58_e9a54e51d3b8/events.out.tfevents.1660449712.e9a54e51d3b8.72.0
#   inflating: /content/wav2vec2-large-en-in/runs/Aug14_03-55-58_e9a54e51d3b8/1660449712.9079666/events.out.tfevents.1660449712.e9a54e51d3b8.72.1
#    creating: /content/wav2vec2-large-en-in/runs/Aug13_21-33-30_a165fbd76f81/1660426721.970452/
#   inflating: /content/wav2vec2-large-en-in/runs/Aug13_21-33-30_a165fbd76f81/events.out.tfevents.1660426721.a165fbd76f81.75.0
#   inflating: /content/wav2vec2-large-en-in/runs/Aug13_21-33-30_a165fbd76f81/1660426721.970452/events.out.tfevents.1660426721.a165fbd76f81.75.1
#   inflating: /content/wav2vec2-large-en-in/checkpoint-1980/scaler.pt
#   inflating: /content/wav2vec2-large-en-in/checkpoint-1980/trainer_state.json
#   inflating: /content/wav2vec2-large-en-in/checkpoint-1980/rng_state.pth
#   inflating: /content/wav2vec2-large-en-in/checkpoint-1980/scheduler.pt
#   inflating: /content/wav2vec2-large-en-in/checkpoint-1980/preprocessor_config.json
#   inflating: /content/wav2vec2-large-en-in/checkpoint-1980/pytorch_model.bin
#   inflating: /content/wav2vec2-large-en-in/checkpoint-1980/optimizer.pt
#   inflating: /content/wav2vec2-large-en-in/checkpoint-1980/training_args.bin
#   inflating: /content/wav2vec2-large-en-in/checkpoint-1980/config.json

# %%
# %%capture
#!pip install datasets==1.18.3
# !pip install transformers==4.17.0
# !pip install jiwer

# %%
import librosa
import re
import json
import numpy as np
import random

# %%
# path to upload checkpoints to drive
from shutil import copyfile
dst = '/usr/local/lib/python3.7/dist-packages/transformers/trainer.py'
src = '/content/drive/MyDrive/trainer_mod_large.py'
copyfile(src, dst)
# Out:
# '/usr/local/lib/python3.7/dist-packages/transformers/trainer.py'

# %%
# %%capture
# !apt install git-lfs

# %%
import IPython
from google.colab import output

display(IPython.display.Javascript('''
 function ClickConnect(){
   btn = document.querySelector("colab-connect-button")
   if (btn != null){
     console.log("Click colab-connect-button"); 
     btn.click() 
     }
   
   btn = document.getElementById('ok')
   if (btn != null){
     console.log("Click reconnect"); 
     btn.click() 
     }
  }
  
setInterval(ClickConnect,60000)
'''))

print("Done.")
# Out:
# Done.

# %% [markdown]
# ### Create Wav2Vec2CTCTokenizer

# %%
from transformers import Wav2Vec2ForCTC, Wav2Vec2FeatureExtractor, Wav2Vec2Processor, Wav2Vec2CTCTokenizer
feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=True)
tokenizer = Wav2Vec2CTCTokenizer.from_pretrained("jonatasgrosman/wav2vec2-large-xlsr-53-english")
processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)
# Out:
# Downloading:   0%|          | 0.00/300 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.50k [00:00<?, ?B/s]

# %%
vocab_dict = tokenizer.get_vocab()
#sort_vocab = sorted((value, key) for (key,value) in vocab_dict.items())
len(vocab_dict)
# Out:
# 33

# %%
max_input_length_in_sec = 13.0
timit_large_train = timit_large_train.filter(lambda x: x < max_input_length_in_sec * processor.feature_extractor.sampling_rate, input_columns=["input_length"])
# Out:
#   0%|          | 0/7 [00:00<?, ?ba/s]

# %% [markdown]
# **Note**: Currently `datasets` make use of [`torchaudio`](https://pytorch.org/audio/stable/index.html) and [`librosa`](https://librosa.org/doc/latest/index.html) for audio loading and resampling. If you wish to implement your own costumized data loading/sampling, feel free to just make use of the `"path"` column instead and disregard the `"audio"` column.

# %% [markdown]
# ## Training
#
# The data is processed so that we are ready to start setting up the training pipeline. We will make use of 🤗's [Trainer](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer) for which we essentially need to do the following:
#
# - Define a data collator. In contrast to most NLP models, XLSR-Wav2Vec2 has a much larger input length than output length. *E.g.*, a sample of input length 50000 has an output length of no more than 100. Given the large input sizes, it is much more efficient to pad the training batches dynamically meaning that all training samples should only be padded to the longest sample in their batch and not the overall longest sample. Therefore, fine-tuning XLSR-Wav2Vec2 requires a special padding data collator, which we will define below
#
# - Evaluation metric. During training, the model should be evaluated on the word error rate. We should define a `compute_metrics` function accordingly
#
# - Load a pretrained checkpoint. We need to load a pretrained checkpoint and configure it correctly for training.
#
# - Define the training configuration.
#
# After having fine-tuned the model, we will correctly evaluate it on the test data and verify that it has indeed learned to correctly transcribe speech.

# %% [markdown]
# ### Set-up Trainer
#
# Let's start by defining the data collator. The code for the data collator was copied from [this example](https://github.com/huggingface/transformers/blob/9a06b6b11bdfc42eea08fa91d0c737d1863c99e3/examples/research_projects/wav2vec2/run_asr.py#L81).
#
# Without going into too many details, in contrast to the common data collators, this data collator treats the `input_values` and `labels` differently and thus applies to separate padding functions on them (again making use of XLSR-Wav2Vec2's context manager). This is necessary because in speech input and output are of different modalities meaning that they should not be treated by the same padding function.
# Analogous to the common data collators, the padding tokens in the labels with `-100` so that those tokens are **not** taken into account when computing the loss.

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %% [markdown]
# Next, the evaluation metric is defined. As mentioned earlier, the
# predominant metric in ASR is the word error rate (WER), hence we will use it in this notebook as well.

# %%
from datasets import load_metric
wer_metric = load_metric("wer")
# Out:
# Downloading builder script:   0%|          | 0.00/1.90k [00:00<?, ?B/s]

# %% [markdown]
# The model will return a sequence of logit vectors:
# $\mathbf{y}_1, \ldots, \mathbf{y}_m$ with $\mathbf{y}_1 = f_{\theta}(x_1, \ldots, x_n)[0]$ and $n >> m$.
#
# A logit vector $\mathbf{y}_1$ contains the log-odds for each word in the vocabulary we defined earlier, thus $\text{len}(\mathbf{y}_i) =$ `config.vocab_size`. We are interested in the most likely prediction of the model and thus take the `argmax(...)` of the logits. Also, we transform the encoded labels back to the original string by replacing `-100` with the `pad_token_id` and decoding the ids while making sure that consecutive tokens are **not** grouped to the same token in CTC style ${}^1$.

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %% [markdown]
# Now, we can load the pretrained `XLSR-Wav2Vec2` checkpoint. The tokenizer's `pad_token_id` must be to define the model's `pad_token_id` or in the case of `Wav2Vec2ForCTC` also CTC's *blank token* ${}^2$. To save GPU memory, we enable PyTorch's [gradient checkpointing](https://pytorch.org/docs/stable/checkpoint.html) and also set the loss reduction to "*mean*".
#
# Because the dataset is quite small (~6h of training data) and because Common Voice is quite noisy, fine-tuning Facebook's [wav2vec2-large-xlsr-53 checkpoint](https://huggingface.co/facebook/wav2vec2-large-xlsr-53) seems to require some hyper-parameter tuning. Therefore, I had to play around a bit with different values for dropout, [SpecAugment](https://arxiv.org/abs/1904.08779)'s masking dropout rate, layer dropout, and the learning rate until training seemed to be stable enough.
#
# **Note**: When using this notebook to train XLSR-Wav2Vec2 on another language of Common Voice those hyper-parameter settings might not work very well. Feel free to adapt those depending on your use case.

# %%
import os
#dics = os.listdir('/content/drive/MyDrive/wav2vec2-base-en-in/wav2vec2-base-en-in')
dics = os.listdir('/content/wav2vec2-large-en-in')

match = [t for t in dics if 'checkpoint' in t]
model_url = '/content/wav2vec2-large-en-in/'+match[0]
print(model_url)
# Out:
# /content/wav2vec2-large-en-in/checkpoint-1980

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    model_url, 
    attention_dropout=0.2,
    hidden_dropout=0.2,
    feat_proj_dropout=0.2,
    mask_time_prob=0.2,
    layerdrop=0.0,
    ctc_loss_reduction="mean", 
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(processor.tokenizer)
)

# %% [markdown]
# The first component of XLSR-Wav2Vec2 consists of a stack of CNN layers that are used to extract acoustically meaningful - but contextually independent - features from the raw speech signal. This part of the model has already been sufficiently trained during pretraining and as stated in the [paper](https://arxiv.org/pdf/2006.13979.pdf) does not need to be fine-tuned anymore.
# Thus, we can set the `requires_grad` to `False` for all parameters of the *feature extraction* part.

# %%
model.freeze_feature_extractor()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:1712: FutureWarning: The method `freeze_feature_extractor` is deprecated and will be removed in Transformers v5.Please use the equivalent `freeze_feature_encoder` method instead.
#   FutureWarning,

# %% [markdown]
# In addition, let's enable gradient checkpointing to save some memory.

# %%
model.gradient_checkpointing_enable()

# %% [markdown]
# In a final step, we define all parameters related to training.
# To give more explanation on some of the parameters:
# - `group_by_length` makes training more efficient by grouping training samples of similar input length into one batch. This can significantly speed up training time by heavily reducing the overall number of useless padding tokens that are passed through the model
# - `learning_rate` and `weight_decay` were heuristically tuned until fine-tuning has become stable. Note that those parameters strongly depend on the Common Voice dataset and might be suboptimal for other speech datasets.
#
# For more explanations on other parameters, one can take a look at the [docs](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer#trainingarguments).
#
# **Note**: If one wants to save the trained models in his/her google drive the commented-out `output_dir` can be used instead.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  # output_dir="/content/gdrive/MyDrive/wav2vec2-large-xlsr-en-in.zip",
  output_dir="/content/wav2vec2-large-en-in",
  #output_dir="./wav2vec2-large-xlsr-turkish-demo",
  group_by_length=True,
  per_device_train_batch_size=8,
  gradient_accumulation_steps=2,
  gradient_checkpointing=True,
  evaluation_strategy="steps",
  num_train_epochs=60,
  fp16=True,
  save_steps=120,
  eval_steps=180,
  logging_steps=120,
  learning_rate=1e-3,
  warmup_steps=1000,
  save_total_limit=1,
)

# %% [markdown]
# Now, all instances can be passed to Trainer and we are ready to start training!

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=timit_large_train,
    eval_dataset=timit_large_test,
    tokenizer=processor.feature_extractor,
)
# Out:
# Using amp half precision backend

# %% [markdown]
# ---
#
# ${}^1$ To allow models to become independent of the speaker rate, in CTC, consecutive tokens that are identical are simply grouped as a single token. However, the encoded labels should not be grouped when decoding since they don't correspond to the predicted tokens of the model, which is why the `group_tokens=False` parameter has to be passed. If we wouldn't pass this parameter a word like `"hello"` would incorrectly be encoded, and decoded as `"helo"`.
#
# ${}^2$ The blank token allows the model to predict a word, such as `"hello"` by forcing it to insert the blank token between the two l's. A CTC-conform prediction of `"hello"` of our model would be `[PAD] [PAD] "h" "e" "e" "l" "l" [PAD] "l" "o" "o" [PAD]`.

# %% [markdown]
# ### Training

# %% [markdown]
# Training will take multiple hours depending on the GPU allocated to this notebook. While the trained model yields somewhat satisfying results on *Common Voice*'s test data of Turkish, it is by no means an optimally fine-tuned model. The purpose of this notebook is to demonstrate how XLSR-Wav2Vec2's [checkpoint](https://huggingface.co/facebook/wav2vec2-large-xlsr-53) can be fine-tuned on a low-resource ASR dataset.
#
# In case you want to use this google colab to fine-tune your model, you should make sure that your training doesn't stop due to inactivity. A simple hack to prevent this is to paste the following code into the console of this tab (*right mouse click -> inspect -> Console tab and insert code*).

# %% [markdown]
# ```javascript
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
# setInterval(ConnectButton,60000);
# ```

# %%
trainer.train(resume_from_checkpoint=True)
# Out:
# Loading model from /content/wav2vec2-large-en-in/checkpoint-1980).
# The following columns in the training set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 6306
#   Num Epochs = 60
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 2
#   Total optimization steps = 23640
#   Continuing training from checkpoint, will skip to saved global_step
#   Continuing training from epoch 5
#   Continuing training from global step 1980
#   Will skip the first 5 epochs then the first 20 batches in the first epoch. If this takes a lot of time, you can add the `--ignore_data_skip` flag to your launch command, but you will resume the training on data already seen by your model.
#   0%|          | 0/20 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='5430' max='23640' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 5430/23640 7:19:49 < 38:42:51, 0.13 it/s, Epoch 13.78/60]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2160</td>
#       <td>0.175300</td>
#       <td>0.187846</td>
#       <td>0.386905</td>
#     </tr>
#     <tr>
#       <td>2340</td>
#       <td>0.167900</td>
#       <td>0.157563</td>
#       <td>0.349283</td>
#     </tr>
#     <tr>
#       <td>2520</td>
#       <td>0.166600</td>
#       <td>0.188843</td>
#       <td>0.356497</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.123900</td>
#       <td>0.165783</td>
#       <td>0.358141</td>
#     </tr>
#     <tr>
#       <td>2880</td>
#       <td>0.123000</td>
#       <td>0.174513</td>
#       <td>0.356680</td>
#     </tr>
#     <tr>
#       <td>3060</td>
#       <td>0.104500</td>
#       <td>0.163862</td>
#       <td>0.352205</td>
#     </tr>
#     <tr>
#       <td>3240</td>
#       <td>0.087400</td>
#       <td>0.196349</td>
#       <td>0.358963</td>
#     </tr>
#     <tr>
#       <td>3420</td>
#       <td>0.106700</td>
#       <td>0.162649</td>
#       <td>0.336134</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.093300</td>
#       <td>0.244720</td>
#       <td>0.384348</td>
#     </tr>
#     <tr>
#       <td>3780</td>
#       <td>0.075700</td>
#       <td>0.172743</td>
#       <td>0.362067</td>
#     </tr>
#     <tr>
#       <td>3960</td>
#       <td>0.087500</td>
#       <td>0.164105</td>
#       <td>0.339786</td>
#     </tr>
#     <tr>
#       <td>4140</td>
#       <td>0.078600</td>
#       <td>0.208890</td>
#       <td>0.349374</td>
#     </tr>
#     <tr>
#       <td>4320</td>
#       <td>0.062000</td>
#       <td>0.162204</td>
#       <td>0.332664</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.066200</td>
#       <td>0.163212</td>
#       <td>0.330746</td>
#     </tr>
#     <tr>
#       <td>4680</td>
#       <td>0.049700</td>
#       <td>0.150354</td>
#       <td>0.329376</td>
#     </tr>
#     <tr>
#       <td>4860</td>
#       <td>0.042900</td>
#       <td>0.181630</td>
#       <td>0.334855</td>
#     </tr>
#     <tr>
#       <td>5040</td>
#       <td>0.042000</td>
#       <td>0.164658</td>
#       <td>0.331933</td>
#     </tr>
#     <tr>
#       <td>5220</td>
#       <td>0.036700</td>
#       <td>0.190658</td>
#       <td>0.335677</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.039800</td>
#       <td>0.167118</td>
#       <td>0.330837</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-2040
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-2040/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-2040/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-2040/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-1980] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-2160
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-2160/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-2160/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-2160/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-2040] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-2280
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-2280/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-2280/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-2280/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-2160] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-2400
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-2400/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-2400/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-2400/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-2280] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-2520
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-2520/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-2520/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-2520/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-2400] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-2640
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-2640/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-2640/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-2640/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-2520] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-2760
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-2760/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-2760/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-2760/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-2640] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-2880
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-2880/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-2880/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-2880/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-2760] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-3000
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-3000/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-3000/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-3000/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-2880] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-3120
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-3120/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-3120/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-3120/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-3000] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-3240
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-3240/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-3240/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-3240/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-3120] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-3360
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-3360/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-3360/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-3360/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-3240] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-3480
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-3480/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-3480/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-3480/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-3360] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-3600
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-3600/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-3600/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-3600/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-3480] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-3720
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-3720/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-3720/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-3720/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-3600] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-3840
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-3840/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-3840/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-3840/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-3720] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-3960
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-3960/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-3960/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-3960/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-3840] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-4080
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-4080/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-4080/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-4080/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-3960] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-4200
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-4200/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-4200/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-4200/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-4080] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-4320
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-4320/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-4320/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-4320/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-4200] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-4440
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-4440/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-4440/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-4440/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-4320] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-4560
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-4560/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-4560/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-4560/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-4440] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-4680
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-4680/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-4680/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-4680/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-4560] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-4800
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-4800/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-4800/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-4800/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-4680] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-4920
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-4920/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-4920/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-4920/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-4800] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-5040
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-5040/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-5040/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-5040/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-4920] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-5160
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-5160/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-5160/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-5160/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-5040] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-5280
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-5280/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-5280/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-5280/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-5160] due to args.save_total_limit
# started backing up to drive, hotfix by Alex
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2286
#   Batch size = 8
# Saving model checkpoint to /content/wav2vec2-large-en-in/checkpoint-5400
# Configuration saved in /content/wav2vec2-large-en-in/checkpoint-5400/config.json
# Model weights saved in /content/wav2vec2-large-en-in/checkpoint-5400/pytorch_model.bin
# Feature extractor saved in /content/wav2vec2-large-en-in/checkpoint-5400/preprocessor_config.json
# Deleting older checkpoint [/content/wav2vec2-large-en-in/checkpoint-5280] due to args.save_total_limit
# started backing up to drive, hotfix by Alex

# %% [markdown]
# The training and validation loss go down nicely. The WER starts improving only at a later stage. Because this notebook is just for demonstration purposes, we can stop here.
#
# To fine-tune larger models on larger datasets using CTC loss, one should take a look at the official speech-recognition examples [here](https://github.com/huggingface/transformers/tree/master/examples/pytorch/speech-recognition#connectionist-temporal-classification-without-language-model-ctc-wo-lm) 🤗.
